# %% [markdown]
# # **第４回 ネットワークの中心性**

# %% [markdown]
# ## **問題１**
# 辺データを`edges/edges01.csv`を読み込み、無向グラフを定義して、代表的な中心性を計算し、ネットワークとして可視化するプログラムを`ns1b_04_01.py`として作成した。ノードの色を中心性の大きさでグラデーションするようにしている。このとき、媒介中心性が最も大きい頂点はどれか。ノード番号の数値を答えよ。

# %%
# ns1b_04_01.py を実行する
# %run ns1b_04_01.py

# %% [markdown]
# ## **問題２**
# ある都市には8個の地区があり、各地区間の距離を考慮して、消防署を配置したい。近接中心性が高い地区に消防署を配置することで、緊急時に迅速な対応ができる。各地区の距離行列を用いて重み付き有向グラフを定義して、代表的な中心性を計算し、ネットワークとして可視化するプログラムを`ns1b_04_02.py`として作成した。ノードの色を中心性の大きさでグラデーションするようにしている。このとき、消防署の配置に適したノード番号の数値を答えよ。また、そのノードの近接中心性の値を小数点以下第３位までの数値で答えよ。

# %%
# ns1b_04_02.py を実行する
# %run ns1b_04_02.py

# %% [markdown]
# ## **問題３**
# Network Repository から以下のインターネットのウェブグラフに関するデータを取得し`edges/`に保存した。このウェブグラフにおいて、PageRankによって検索順位が最上位になるウェブページを抽出したい。データを読み込み有向グラフを定義して、PageRankを計算するプログラムを`ns1b_04_03.py`として作成した。このとき、最上位になるWebページに該当するノード番号を答えよ。ただし、PageRankアルゴリズムのパラメータ$\alpha=0.85$とすること。

# %%
# ns1b_04_03.py を実行する
# %run ns1b_04_03.py
