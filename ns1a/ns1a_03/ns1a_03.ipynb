# %% [markdown]
# # **第３回　次数と次数分布、スケールフリーネットワーク**

# %% [markdown]
# ## **問題１**
# `img/img1.jpg`の画像として与えられた以下のグラフを定義して次数分布を可視化、平均次数を計算するプログラムを`ns1_03_01.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。ただし、グラフの定義が正しくできているかを確認するため、グラフを可視化するプログラムも記載されている。
#
# <img src="img/img1.jpg">

# %%
# ns1a_03_01.py を実行する
# %run ns1a_03_01.py

# %% [markdown]
# ## **問題２**
# `img/img2.jpg`の画像として与えられた以下のグラフの有向辺リストを、`edges/edges2.csv`として定義して、入次数と出次数に対する次数分布を可視化、それぞれの平均次数を計算するプログラムを`ns1_03_02.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。ただし、グラフの定義が正しくできているかを確認するため、グラフを可視化するプログラムも記載されている。
#
# <img src="img/img2.jpg">

# %%
# ns1a_03_02.py を実行する
# %run ns1a_03_02.py

# %% [markdown]
# ## **問題３**
# スケールフリー性が期待される辺リストを、`edges/scale_free_network_edges.csv`として読み込み、グラフを定義して可視化、その後、次数分布をベキ分布としてフィッティングするプログラムを`ns1_03_03.py`として作成した。フィッティングによって得られたべき指数を答えよ。

# %%
# ns1a_03_03.py を実行する
# %run ns1a_03_03.py
