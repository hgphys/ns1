# %% [markdown]
# # **第７回　実践演習：スモールワールド性の検証**

# %% [markdown]
# ## **問題１**
# Googleフォームで受講生の友人関係調査を行った。`ns1a_06`において前処理した頂点データと辺データを`data01/nodes01.csv`と`data/edges01.txt`として保存せよ。これらのデータを読み込み、受講生間の友人関係ネットワークのスモールワールド性を検証するプログラムを`ns1a_07_01.py`として作成した。グラフのランダム化により人工ネットワークを作成するモジュールを`rg.py`として利用している。このとき、次数保存ランダム化したネットワークのクラスタ係数はいくつか答えよ。

# %%
# ns1a_07_01.py を実行する
# %run ns1a_07_01.py

# %% [markdown]
# ## **問題２**
# ネットワーク科学研究者間の共著ネットワークのデータを以下のリンクから取得して、辺データを`data02/`に保存せよ。このデータは、頂点が研究者、論文の共著歴があった場合、無向辺が定義されている。
#
# https://networkrepository.com/ca-netscience.php
#
# この辺データ読込み、ネットワークネットワークのスモールワールド性を検証するプログラムを`ns1a_07_02.py`として作成した。このとき、次数保存ランダム化したネットワークのクラスタ係数はいくつか答えよ。

# %%
# ns1a_07_02.py を実行する
# %run ns1a_07_02.py

# %% [markdown]
# ## **問題３**
# ハーバード大学のFacebook友人関係ネットワークのデータを以下のリンクから取得して、辺データを`data03/`に保存せよ。このデータは、頂点がFacebookユーザ、ユーザ間の友人関係の有無を無向辺としてモデル化したものである。
#
# https://networkrepository.com/socfb-Haverford76.php
#
# この辺データ読込み、ネットワークネットワークのスモールワールド性を検証するプログラムを`ns1a_07_03.py`として作成した。このとき、次数保存ランダム化したネットワークのクラスタ係数はいくつか答えよ。

# %%
# ns1a_07_03.py を実行する
# %run ns1a_07_03.py
