# %% [markdown]
# # **第４回　経路と距離、クラスタ係数、スモールワールドネットワーク**

# %% [markdown]
# ## **問題１**
# `img/img1.jpg`の画像として与えられた以下のグラフを定義して平均最短経路長と平均クラスタ係数を計算するプログラムを`ns1a_04_01.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。ただし、グラフの定義が正しくできているかを確認するため、グラフを可視化するプログラムも記載されている。
#
# <img src="img/img1.jpg">

# %%
# ns1a_04_01.py を実行する
# %run ns1a_04_01.py

# %% [markdown]
# ## **問題２**
# スケールフリー性が確認された辺リストを、`edges/scale_free_network_edges.csv`として読み込み、グラフを定義して可視化、平均最短経路長と平均クラスタ係数を計算するプログラムを`ns1a_04_02.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。

# %%
# ns1a_04_02.py を実行する
# %run ns1a_04_02.py

# %% [markdown]
# ## **問題３**
# Watts-Strogatzモデルに基づくグラフを生成して可視化、その後、平均最短経路長と平均クラスタ係数を計算するプログラムを`ns1a_04_03.py`として作成した。Watts-Strogatzモデルは、正則グラフを貼り替えることで、ランダムグラフに近づける。張り替え前の正則グラフの平均最短経路長と平均クラスタ係数を求めよ。

# %%
# ns1a_04_03.py を実行する
# %run ns1a_04_03.py
