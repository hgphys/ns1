# %% [markdown]
# # **第５回　実践演習：ネットワークデータのモデル化**

# %% [markdown]
# ## **問題１**
# Googleフォームで受講生の友人関係調査を行った。この友人関係ネットワークをネットワーク分析したい。はじめにアンケートの回答について、正しく回答名が記入されているかについて確認したい。回答データと受講生リストを読み込み、メールアドレスを元に結合したものを`data/data_merged.csv`として出力するプログラムを`ns1a_05_01.py`として作成した。Moodleコースのリンクから、アンケート結果をCSVファイルとしてダウンロードして、`data`フォルダに保存した上でプログラムを完成させよ。アンケートの回答名と受講者名の一致している数はいくつか。

# %%
# ns1a_05_01.py を実行する
# %run ns1a_05_01.py

# %% [markdown]
# ## **問題２**
# 問題１で作成した`data/data_merged.csv`を読込み、受講者名と友人リストを元に無向グラフを定義して、辺データ`edges/friend_edges.txt`として出力するプログラムを`ns1a_05_02.py`として作成した。ただし、受講者名と友人リストの氏名のスペースが、全角と半角で異なるため、氏名の姓を頂点名とするプログラムとしている。このとき、グラフの辺（エッジ）数はいくつか。

# %%
# ns1a_05_02.py を実行する
# %run ns1a_05_02.py

# %% [markdown]
# ## **問題３**
# 問題２で作成した辺データ`edges/friend_edges.txt`を読込み、受講生間の友人関係ネットワークを可視化、ネットワークと次数分布を可視化、平均次数と最大次数の頂点を特定するプログラムを`ns1a_05_03.py`として作成した。平均次数と次数が最大の頂点、その次数を答えよ。

# %%
# ns1a_05_03.py を実行する
# %run ns1a_05_03.py
