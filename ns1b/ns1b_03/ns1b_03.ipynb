# %% [markdown]
# # **第３回 ネットワークの連結性**

# %% [markdown]
# ## **問題１**
# 辺データを`edges/edges01.csv`を読み込み、無向グラフを定義して、その最大連結成分を計算するプログラムを`ns1b_03_01.py`として作成した。このとき、最大連結成分の大きさはいくつか答えよ。

# %%
# ns1b_03_01.py を実行する
# %run ns1b_03_01.py

# %% [markdown]
# ## **問題２**
# 辺データを`edges/edges02.csv`を読み込み、有向グラフを定義して、その最大弱連結成分と最大強連結を計算するプログラムを`ns1b_03_02.py`として作成した。このとき、最大弱連結成分と最大強連結成分の大きさはそれぞれいくつか答えよ。

# %%
# ns1b_03_02.py を実行する
# %run ns1b_03_02.py

# %% [markdown]
# ## **問題３**
# 辺データを`edges/edges03.csv`を読み込み、無向グラフを定義して、その最大連結成分を計算するプログラムを`ns1b_03_03.py`として作成した。このとき、次数が最大の頂点を除去した場合、最大連結成分の大きさはいくつになるか答えよ。

# %%
# ns1b_03_03.py を実行する
# %run ns1b_03_03.py
