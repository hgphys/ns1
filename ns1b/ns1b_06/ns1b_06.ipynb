# %% [markdown]
# # **第６回 ネットワーク中心性の比較**

# %% [markdown]
# ## **問題１**
# 路線ネットワークを分析するために、以下のサイトから路線・駅・結合に関するデータをダウンロードしたものを`data/`に保存した。
# - 駅データ https://ekidata.jp/ 2023年3月27日時点
#
# 駅の住所に「名古屋」が含まれている駅を抽出し、その駅が含まれる路線ネットワークを可視化するプログラムを`ns1b_06_01.py`として作成した。ネットワークの頂点数はいくつか。

# %%
# ns1b_06_01.py を実行する
# %run ns1b_06_01.py

# %% [markdown]
# ## **問題２**
# 問題１に引き続き、名古屋の鉄道路線のネットワークを分析する。接続データから定義できる最大連結成分に対して、各種ネットワーク中心性を求めるプログラムを`ns1b_06_02.py`として作成した。このとき、駅グループコードを利用して、乗り換え可能駅を同一駅とし、結果を`output.csv`として出力している。
# - 駅データ＞仕様書＞駅グループコード仕様 https://ekidata.jp/doc/station_g.php
#
# このとき、次数中心性、媒介中心性が最大となる駅名をそれぞれ答えよ。

# %%
# ns1b_06_02.py を実行する
# %run ns1b_06_02.py
