# %% [markdown]
# # **第２回 グラフ理論：ネットワークとグラフ**

# %% [markdown]
# ## **問題１**
# `img/img1.jpg`の画像として与えられた以下のグラフを定義してネットワークの特徴量の一つである密度を計算するプログラムを`ns1_02_01.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。ただし、グラフの定義が正しくできているかを確認するため、グラフを可視化するプログラムも記載されている。
#
# <img src="img/img1.jpg">

# %%
# ns1a_02_01.py を実行する
# %run ns1a_02_01.py

# %% [markdown]
# ## **問題２**
# `img/img2.jpg`の画像として与えられた以下のグラフの有向辺リストを、`edges/edges2.csv`として定義してネットワークの特徴量の一つである密度を計算するプログラムを`ns1_02_02.py`として作成した。誤りを含むため、CSVファイルとPythonファイルを修正し、正しい出力結果を答えよ。ただし、グラフの定義が正しくできているかを確認するため、グラフを可視化するプログラムも記載されている。
#
# <img src="img/img2.jpg">

# %%
# ns1a_02_02.py を実行する
# %run ns1a_02_02.py

# %% [markdown]
# ## **問題３**
# 無向グラフの辺リストを、`edges/edges3.csv`として定義してネットワークの大きさ（頂点数）を計算するプログラムを`ns1_02_03.py`として作成した。誤りを含むため、Pythonファイルを修正し、正しい出力結果を答えよ。

# %%
# ns1a_02_03.py を実行する
# %run ns1a_02_03.py
