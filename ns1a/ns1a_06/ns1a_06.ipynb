# %% [markdown]
# # **第６回　実践演習：ネットワーク特長量の計算**

# %% [markdown]
# ## **問題１**
# Googleフォームで受講生の友人関係調査を行った。`ns1a_05`のデータを前処理した頂点データおよび辺データを`data01/nodes01.csv`と`data/edges01.txt`として保存せよ。受講生間の友人関係ネットワークの特徴量（次数、クラスタ係数）を計算して、頂点データに追加し、`data01/output01.csv`として出力するプログラムを`ns1a_06_01.py`として作成した。このとき、平均クラスタ係数はいくつか。小数点第４位を四捨五入して答えよ。

# %%
# ns1a_06_01.py を実行する
# %run ns1a_06_01.py

# %% [markdown]
# ## **問題２**
# 政治家の関係ネットワークのデータを以下のリンクから取得して、辺データを`data02/`に保存せよ。このデータは、頂点が政治家、政治家のFacebookページが相互に「いいね」されている場合、無向辺が定義されている。
#
# https://networkrepository.com/fb-pages-politician.php
#
# この辺データ読込み、ネットワークと次数分布を可視化、ネットワークの特徴量（次数、クラスタ係数）を計算して、頂点データを作成し、`data02/output02.csv`として出力するプログラムを`ns1a_06_02.py`として作成した。平均次数と平均クラスタ係数、平均最短経路長を答えよ。

# %%
# ns1a_06_02.py を実行する
# %run ns1a_06_02.py

# %% [markdown]
# ## **問題３**
# カリフォルニアの道路交通ネットワークのデータを以下のリンクから取得して、辺データを`data03/`に保存せよ。このデータは、頂点が交差点か行き止まり、これらをつなぐ道路の有無を無向辺としてモデル化したものである。
#
# https://snap.stanford.edu/data/roadNet-CA.html
#
# この辺データ読込み、ネットワークと次数分布を可視化、ネットワークの特徴量（次数、クラスタ係数）を計算して、頂点データを作成し、`data/output03.csv`として出力するプログラムを`ns1a_06_03.py`として作成した。平均次数と平均クラスタ係数、最大連結成分の頂点数を答えよ。

# %%
# ns1a_06_03.py を実行する
# %run ns1a_06_03.py
