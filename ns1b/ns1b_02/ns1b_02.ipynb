# %% [markdown]
# # **第２回 グラフ理論：ネットワークとグラフ**

# %% [markdown]
# ## **問題１**
# `img/img1.jpg`の画像として与えられた以下のグラフを隣接行列を用いて定義してネットワークの特徴量の一つである密度を計算するプログラムを`ns1b_02_01.py`として作成した。誤りを含むため、エラーを修正し、正しい出力結果を答えよ。ただし、グラフの定義が正しくできているかを確認するため、グラフを可視化するプログラムも記載されている。
#
# <img src="img/img1.jpg">

# %%
# ns1b_02_01.py を実行する
# %run ns1b_02_01.py

# %% [markdown]
# ## **問題２**
# `img/img2.jpg`の画像として与えられた以下のグラフの有向辺リストを、`edges/edges2.csv`として定義、読込みネットワークとして可視化、その隣接行列を出力するプログラムを`ns1b_02_02.py`として作成した。隣接行列の３行目の行和と３列目の列和を求めよ。
#
#
# <img src="img/img2.jpg">

# %%
# ns1b_02_02.py を実行する
# %run ns1b_02_02.py

# %% [markdown]
# ## **問題３**
# 無向グラフの辺リストを、`edges/edges3.csv`として定義して隣接行列を取得、隣接行列の３乗を計算することで、ネットワークに存在する三角形の数を取得するプログラムを`ns1b_02_03.py`として作成した。ネットワークに存在する三角形はいくつあるか。ただし、コードは完成のため、Pythonファイルを修正し、正しい出力結果を答えよ。

# %%
# ns1b_02_03.py を実行する
# %run ns1b_02_03.py
