# %% [markdown]
# # **第５回 ネットワークの生成**

# %% [markdown]
# ## **問題１**
# 金沢学院大学の教員情報を取得するためにウェブスクレイピングを行うプログラムを`ns1b_05_01.py`として作成した。以下のURLに記載されている教員の氏名と専門分野の一部を取得して、`data/data.csv`に保存するものである。このとき、教員紹介ページに何人の教員が紹介されているか。ただし、重複は除くこと。
# - 金沢学院大学＞金沢学院大学について＞教員紹介 https://www.kanazawa-gu.ac.jp/aboutus/teacher/

# %%
# ns1b_05_01.py を実行する
# %run ns1b_05_01.py

# %% [markdown]
# ## **問題２**
# Barabasi-Albertモデルを利用して、スケールフリー・ネットワークを生成し、そのネットワークと次数分布を可視化し、ネットワーク特徴量を計算するプログラムを`ns1b_05_02.py`として作成した。このとき、次数中心性が最も高くなる頂点はどのような頂点か。以下の中から一つ選べ。
# - 頂点番号 1〜10
# - 頂点番号 11〜100
# - 頂点番号 101〜500

# %%
# ns1b_05_02.py を実行する
# %run ns1b_05_02.py
