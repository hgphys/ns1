# %% [markdown]
# # **第７回 ネットワークの頑強性**

# %% [markdown]
# ## **問題１**
# ランダム・ネットワークの頑強性を評価するプログラムを`ns1b_07_01.py`として作成した。このとき、以下の選択肢の中から最も適切な説明を選べ。ただし、選択的なノード除去は次数が大きいものを優先的に除去している。
# - ランダムなノード除去に耐性があり、選択的なノード除去に脆弱なネットワーク
# - 選択的なノード除去に耐性があり、ランダムなノード除去に対して脆弱なネットワーク
# - ランダムなノード除去にも選択的なノード除去にもある程度の耐性があるネットワーク
# - ランダムなノード除去にも選択的なノード除去にも脆弱なネットワーク

# %%
# ns1b_07_01.py を実行する
# %run ns1b_07_01.py

# %% [markdown]
# ## **問題２**
# スケールフリー・ネットワークの頑強性を評価するプログラムを`ns1b_07_02.py`として作成した。このとき、以下の選択肢の中から最も適切な説明を選べ。ただし、選択的なノード除去は次数が大きいものを優先的に除去している。
# - ランダムなノード除去に耐性があり、選択的なノード除去に脆弱なネットワーク
# - 選択的なノード除去に耐性があり、ランダムなノード除去に対して脆弱なネットワーク
# - ランダムなノード除去にも選択的なノード除去にもある程度の耐性があるネットワーク
# - ランダムなノード除去にも選択的なノード除去にも脆弱なネットワーク

# %%
# ns1b_07_02.py を実行する
# %run ns1b_07_02.py
